# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv('Cost_of_Living_Index_by_Country_2024.csv')
print(dataset.describe())

x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values
print(x)
# Out:
#              Rank  Cost of Living Index  Rent Index  \
# count  121.000000            121.000000  121.000000
# mean    61.000000             43.555372   16.052893
# std     35.073732             16.147574   11.412267
# min      1.000000             18.800000    2.400000
# 25%     31.000000             30.200000    8.500000
# 50%     61.000000             39.500000   12.400000
# 75%     91.000000             52.800000   20.100000
# max    121.000000            101.100000   67.200000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                      121.000000       121.000000
# mean                        30.357851        44.228926
# std                         13.263721        17.055109
# min                         11.100000        17.500000
# 25%                         19.800000        31.600000
# 50%                         27.000000        40.500000
# 75%                         37.000000        53.700000
# ...

# %%
# Replace 'Cost_of_Living_Index_by_Country_2024.csv' with the path to your file if it's in a different directory.
data = pd.read_csv('Cost_of_Living_Index_by_Country_2024.csv')

# Display the first few rows of the data
data.head()

print(data.isnull().sum())
# Out:
# Rank                              0
# Country                           0
# Cost of Living Index              0
# Rent Index                        0
# Cost of Living Plus Rent Index    0
# Groceries Index                   0
# Restaurant Price Index            0
# Local Purchasing Power Index      0
# dtype: int64

# %%
# calculating standard deviation of the cost of living index

cost_of_living_indices = data['Cost of Living Index']
mean = np.mean(cost_of_living_indices)
standard_deviation = np.std(cost_of_living_indices)

print('Standard Deviation of Cost of Living Index:', standard_deviation)
print('Mean of Cost of Living Index:', mean)
# Out:
# Standard Deviation of Cost of Living Index: 16.080710432135316
# Mean of Cost of Living Index: 43.555371900826444

# %%
dataset.iloc[:,:-1].values
# Out:
# array([[1, 'Switzerland', 101.1, 46.5, 74.9, 109.1, 97.0],
#        [2, 'Bahamas', 85.0, 36.7, 61.8, 81.6, 83.3],
#        [3, 'Iceland', 83.0, 39.2, 62.0, 88.4, 86.8],
#        [4, 'Singapore', 76.7, 67.2, 72.1, 74.6, 50.4],
#        [5, 'Barbados', 76.6, 19.0, 48.9, 80.8, 69.4],
#        [6, 'Norway', 76.0, 26.2, 52.1, 79.0, 73.5],
#        [7, 'Denmark', 72.3, 26.4, 50.2, 64.8, 81.3],
#        [8, 'Hong Kong (China)', 70.8, 59.4, 65.3, 84.6, 46.2],
#        [9, 'United States', 70.4, 41.7, 56.6, 75.0, 67.2],
#        [10, 'Australia', 70.2, 33.4, 52.5, 77.3, 62.5],
#        [11, 'Austria', 65.1, 22.5, 44.7, 66.4, 59.3],
#        [12, 'Canada', 64.8, 33.2, 49.6, 71.2, 61.7],
#        [13, 'New Zealand', 64.6, 25.9, 46.0, 71.9, 57.1],
#        [14, 'Ireland', 64.4, 42.3, 53.8, 59.3, 65.3],
#        [15, 'France', 63.7, 21.0, 43.2, 69.5, 56.3],
#        [16, 'Puerto Rico', 63.3, 19.5, 42.3, 64.1, 53.1],
#        [17, 'Finland', 63.2, 19.7, 42.4, 63.0, 63.6],
# ...
